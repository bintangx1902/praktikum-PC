# %%
# !pip install easyocr
# !pip install imutils

# %% [markdown]
# ## IMPORTING LIBARRY

# %%
import cv2 as cv
from matplotlib import pyplot as plt
import numpy as np
import imutils
import easyocr

# %% [markdown]
# ## READ IMAGE, GRAYSCALE AND BLUR

# %%
img = cv.imread('./data.jpg')
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
plt.imshow(cv.cvtColor(gray, cv.COLOR_BGR2RGB))

# %% [markdown]
# ## APPLY FILTERS AND FIND EDGES

# %%
b_filter = cv.bilateralFilter(gray, 10, 20, 20) # Noise Reduction
edged = cv.Canny(b_filter, 100, 300)
plt.imshow(cv.cvtColor(edged, cv.COLOR_BGR2RGB))

# %% [markdown]
# ## FIND CONTOURS AND APPLY MASK

# %%
key_points = cv.findContours(edged.copy(), cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
contours = imutils.grab_contours(key_points)
contours = sorted(contours, key=cv.contourArea, reverse=True)[:10]

# %%
location = None
for contour in contours:
    approx = cv.approxPolyDP(contour, 10, True)
    if len(approx) == 4:
        location = approx
        break

# %%
location
# Out:
# array([[[1142,  563]],
#
#        [[1205,  569]],
#
#        [[1209,  674]],
#
#        [[1153,  670]]], dtype=int32)

# %%
mask = np.zeros(gray.shape, np.uint8)
new_img = cv.drawContours(mask, [location], 0, 255, -1)
new_img = cv.bitwise_and(img, img, mask=mask)

# %%
plt.imshow(new_img)
